# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat.csv')

# %%
df.head(10)
# Out:
#    V1    V2 V3   V4
# 0   2  13.0  B  1.0
# 1  -1   7.0  B  1.0
# 2   0  11.0  A  0.0
# 3   2  11.0  A  2.0
# 4   0  10.0  B -1.0
# 5   2  11.0  A  0.0
# 6   0   9.0  A  2.0
# 7   1   9.0  A  1.0
# 8   0   9.0  B  2.0
# 9  -1  10.0  A  0.0

# %% [markdown]
# В переменную с именем subset_1 сохраните только первые 10 наблюдений и только 1 и 3 колонку.

# %%
df_first_10 = df.loc[0:9]
subset_1 = df_first_10[['V1', 'V3']]

# %%
subset_1
# Out:
#    V1 V3
# 0   2  B
# 1  -1  B
# 2   0  A
# 3   2  A
# 4   0  B
# 5   2  A
# 6   0  A
# 7   1  A
# 8   0  B
# 9  -1  A

# %% [markdown]
# В переменную с именем subset_2 сохраните все наблюдения кроме 1 и 5 и только 2 и 4 колонку.

# %%
excepted_rows_df = df.index.isin([0,])
filtered_rows = df[~excepted_rows_df]
subset_2 = filtered_rows[['V2', 'V4']]

# %%
filtered_rows.head(10)
# Out:
#     V1    V2 V3   V4
# 0    2  13.0  B  1.0
# 2    0  11.0  A  0.0
# 3    2  11.0  A  2.0
# 4    0  10.0  B -1.0
# 6    0   9.0  A  2.0
# 7    1   9.0  A  1.0
# 8    0   9.0  B  2.0
# 9   -1  10.0  A  0.0
# 10   1  10.0  A  1.0
# 11  -2  10.0  A  1.0

# %%
df['V5']=df['V1']+df['V4']
df['V6'] = np.log(df.V2)

# %%
df
# Out:
#      V1    V2 V3   V4   V5        V6
# 0     2  13.0  B  1.0  3.0  2.564949
# 1    -1   7.0  B  1.0  0.0  1.945910
# 2     0  11.0  A  0.0  0.0  2.397895
# 3     2  11.0  A  2.0  4.0  2.397895
# 4     0  10.0  B -1.0 -1.0  2.302585
# 5     2  11.0  A  0.0  2.0  2.397895
# 6     0   9.0  A  2.0  2.0  2.197225
# 7     1   9.0  A  1.0  2.0  2.197225
# 8     0   9.0  B  2.0  2.0  2.197225
# 9    -1  10.0  A  0.0 -1.0  2.302585
# 10    1  10.0  A  1.0  2.0  2.302585
# 11   -2  10.0  A  1.0 -1.0  2.302585
# 12    0   8.0  B  0.0  0.0  2.079442
# 13    1  12.0  A  3.0  4.0  2.484907
# 14   -1  10.0  A  2.0  1.0  2.302585
# 15    2  10.0  B  1.0  3.0  2.302585
# 16    0   9.0  B  1.0  1.0  2.197225
# 17    0  11.0  A  0.0  0.0  2.397895
# 18    0   8.0  A  1.0  1.0  2.079442
# 19    0  10.0  A  1.0  1.0  2.302585
# 20    1  10.0  B  2.0  3.0  2.302585
# 21    3  10.0  A  2.0  5.0  2.302585
# 22   -2  12.0  A  3.0  1.0  2.484907
# 23   -1  11.0  B  3.0  2.0  2.397895
# ...

# %%
 df.rename(index=str, columns={"V1": "session_value",\
                               "V2": "group",\
                              "V3":"time", \
                              "V4":"n_users"})
# Out:
#      session_value  group time  n_users   V5        V6
# 0                2   13.0    B      1.0  3.0  2.564949
# 1               -1    7.0    B      1.0  0.0  1.945910
# 2                0   11.0    A      0.0  0.0  2.397895
# 3                2   11.0    A      2.0  4.0  2.397895
# 4                0   10.0    B     -1.0 -1.0  2.302585
# 5                2   11.0    A      0.0  2.0  2.397895
# 6                0    9.0    A      2.0  2.0  2.197225
# 7                1    9.0    A      1.0  2.0  2.197225
# 8                0    9.0    B      2.0  2.0  2.197225
# 9               -1   10.0    A      0.0 -1.0  2.302585
# 10               1   10.0    A      1.0  2.0  2.302585
# 11              -2   10.0    A      1.0 -1.0  2.302585
# 12               0    8.0    B      0.0  0.0  2.079442
# 13               1   12.0    A      3.0  4.0  2.484907
# 14              -1   10.0    A      2.0  1.0  2.302585
# 15               2   10.0    B      1.0  3.0  2.302585
# ...
