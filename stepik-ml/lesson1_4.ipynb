# %%
import pandas as pd
import numpy as np

# %%
students_performance = pd.read_csv('http://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

# %%
students_performance.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
filtered = students_performance[(students_performance['writing score'] > 50) & (students_performance.gender == 'male')]

# %%
filtered
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 4     male        group C                some college      standard
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 13    male        group A                some college      standard
# 16    male        group C                 high school      standard
# 20    male        group D                 high school      standard
# 22    male        group D                some college      standard
# 24    male        group D           bachelor's degree  free/reduced
# 25    male        group A             master's degree  free/reduced
# 26    male        group B                some college      standard
# 28    male        group C                 high school      standard
# 34    male        group E                some college      standard
# 35    male        group E          associate's degree      standard
# ...

# %%
filtered = students_performance[students_performance.lunch == 'free/reduced']

# %%
len(filtered.index)/len(students_performance.index)
# Out:
# 0.355

# %%
free_reduced = students_performance[students_performance.lunch == 'free/reduced']
standart_lunch = students_performance[students_performance.lunch == 'standard']

# %%
free_reduced.mean()
# Out:
# math score       58.921127
# reading score    64.653521
# writing score    63.022535
# dtype: float64

# %%
standart_lunch.mean()
# Out:
# math score       70.034109
# reading score    71.654264
# writing score    70.823256
# dtype: float64

# %%
free_reduced.var()
# Out:
# math score       229.824270
# reading score    221.871139
# writing score    238.202881
# dtype: float64

# %%
standart_lunch.var()
# Out:
# math score       186.418089
# reading score    191.285560
# writing score    205.620887
# dtype: float64
